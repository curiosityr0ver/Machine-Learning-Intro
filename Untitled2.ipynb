# %% [markdown]
# <a href="https://colab.research.google.com/github/curiosityr0ver/Machine-Learning-Intro/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as mp

# %%
df = pd.read_csv("sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
x = pd.Series(["BMW", "Toyota", "Audi"])
x
# Out:
# 0       BMW
# 1    Toyota
# 2      Audi
# dtype: object

# %%
y = pd.DataFrame({("Toyota", "Corolla"), ("BMW", "M5 Coupe"), ("Audi", "A5 Sportback")})
y
# Out:
#         0             1
# 0  Toyota       Corolla
# 1     BMW      M5 Coupe
# 2    Audi  A5 Sportback

# %% [markdown]
# ## Data Description

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
len(df)
# Out:
# 3000

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.loc[5]
# Out:
# longitude              -119.5600
# latitude                 36.5100
# housing_median_age       37.0000
# total_rooms            1018.0000
# total_bedrooms          213.0000
# population              663.0000
# households              204.0000
# median_income             1.6635
# median_house_value    67000.0000
# Name: 5, dtype: float64

# %%
df.loc[0:10:3]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 3        49.0        11.0         6.1359            330000.0
# 6       604.0       218.0         1.6641             67000.0
# 9      2830.0       603.0         2.3333            164200.0

# %%
df.longitude
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
sls = pd.read_csv("car_sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-13b4bfc0c5be> in <module>
# ----> 1 sls = pd.read_csv("car_sales.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
sls.head()

# %%
pd.crosstab(sls["Make"],sls["Doors"])

# %%
sls.groupby(["Make"]).mean()

# %%
sls["Odometer (KM)"].plot()

# %%
sls["Price"].plot()
sls["Price"].mean()

# %%
sls["Make"] = sls["Make"].str.lower()
sls.head()

# %%
miss = pd.read_csv("brittleness-index.csv")
miss.head()
miss["TK105"].fillna(miss["TK105"].mean(), inplace = True)
miss.head()
len(miss)

# %%
miss = pd.read_csv("carMiss.csv")

# %%
miss.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
miss["Odometer"].fillna(5599.23, inplace = True)

# %%
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price
# 0  Toyota  White  150043.00    4.0   $4,000
# 1   Honda    Red   87899.00    4.0   $5,000
# 2  Toyota   Blue    5599.23    3.0   $7,000
# 3     BMW  Black   11179.00    5.0  $22,000
# 4  Nissan  White  213095.00    4.0   $3,500

# %%
seats = pd.Series([4,4,5,4,6,5,4,6,4,4])
miss["seats"] = seats

# %%
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  seats
# 0  Toyota  White  150043.00    4.0   $4,000      4
# 1   Honda    Red   87899.00    4.0   $5,000      4
# 2  Toyota   Blue    5599.23    3.0   $7,000      5
# 3     BMW  Black   11179.00    5.0  $22,000      4
# 4  Nissan  White  213095.00    4.0   $3,500      6

# %%
sales = pd.Series([1200, 400, 800, 1400, 500, 2000, 1800, 1500, 1900, 2300])
miss["sales"] = sales

# %%
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  seats  sales
# 0  Toyota  White  150043.00    4.0   $4,000      4   1200
# 1   Honda    Red   87899.00    4.0   $5,000      4    400
# 2  Toyota   Blue    5599.23    3.0   $7,000      5    800
# 3     BMW  Black   11179.00    5.0  $22,000      4   1400
# 4  Nissan  White  213095.00    4.0   $3,500      6    500

# %%
miss["fuel_burnt"] = miss["Odometer"]/100 * miss["seats"]
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  seats  sales  fuel_burnt
# 0  Toyota  White  150043.00    4.0   $4,000      4   1200   6001.7200
# 1   Honda    Red   87899.00    4.0   $5,000      4    400   3515.9600
# 2  Toyota   Blue    5599.23    3.0   $7,000      5    800    279.9615
# 3     BMW  Black   11179.00    5.0  $22,000      4   1400    447.1600
# 4  Nissan  White  213095.00    4.0   $3,500      6    500  12785.7000

# %%
miss["seats"] = 4
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  seats  sales  fuel_burnt
# 0  Toyota  White  150043.00    4.0   $4,000      4   1200   6001.7200
# 1   Honda    Red   87899.00    4.0   $5,000      4    400   3515.9600
# 2  Toyota   Blue    5599.23    3.0   $7,000      4    800    279.9615
# 3     BMW  Black   11179.00    5.0  $22,000      4   1400    447.1600
# 4  Nissan  White  213095.00    4.0   $3,500      4    500  12785.7000

# %%
miss["Pollution_check"] = True
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  seats  sales  fuel_burnt  \
# 0  Toyota  White  150043.00    4.0   $4,000      4   1200   6001.7200
# 1   Honda    Red   87899.00    4.0   $5,000      4    400   3515.9600
# 2  Toyota   Blue    5599.23    3.0   $7,000      4    800    279.9615
# 3     BMW  Black   11179.00    5.0  $22,000      4   1400    447.1600
# 4  Nissan  White  213095.00    4.0   $3,500      4    500  12785.7000
#
#    Pollution_check
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True

# %%
miss.drop("seats", axis = 1, inplace = True)
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price  sales  fuel_burnt  \
# 0  Toyota  White  150043.00    4.0   $4,000   1200   6001.7200
# 1   Honda    Red   87899.00    4.0   $5,000    400   3515.9600
# 2  Toyota   Blue    5599.23    3.0   $7,000    800    279.9615
# 3     BMW  Black   11179.00    5.0  $22,000   1400    447.1600
# 4  Nissan  White  213095.00    4.0   $3,500    500  12785.7000
#
#    Pollution_check
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True

# %%
miss.sample(frac = 1)
# Out:
#      Make Colour   Odometer  Doors    Price  sales  fuel_burnt  \
# 8  Toyota  White   60000.00    NaN      NaN   1900   2400.0000
# 7   Honda   Blue    5599.23    4.0      NaN   1500    335.9538
# 3     BMW  Black   11179.00    5.0  $22,000   1400    447.1600
# 1   Honda    Red   87899.00    4.0   $5,000    400   3515.9600
# 4  Nissan  White  213095.00    4.0   $3,500    500  12785.7000
# 9     NaN  White   31600.00    4.0   $9,700   2300   1264.0000
# 5  Toyota  Green    5599.23    4.0   $4,500   2000    279.9615
# 2  Toyota   Blue    5599.23    3.0   $7,000    800    279.9615
# 0  Toyota  White  150043.00    4.0   $4,000   1200   6001.7200
# 6   Honda    NaN    5599.23    4.0   $7,500   1800    223.9692
#
#    Pollution_check
# 8             True
# 7             True
# 3             True
# 1             True
# 4             True
# 9             True
# 5             True
# 2             True
# 0             True
# 6             True

# %%
miss["sales"] = miss["sales"].apply(lambda x: x*10)
miss.head()
# Out:
#      Make Colour   Odometer  Doors    Price   sales  fuel_burnt  \
# 0  Toyota  White  150043.00    4.0   $4,000  1200.0   6001.7200
# 1   Honda    Red   87899.00    4.0   $5,000   400.0   3515.9600
# 2  Toyota   Blue    5599.23    3.0   $7,000   800.0    279.9615
# 3     BMW  Black   11179.00    5.0  $22,000  1400.0    447.1600
# 4  Nissan  White  213095.00    4.0   $3,500   500.0  12785.7000
#
#    Pollution_check
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
